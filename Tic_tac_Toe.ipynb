# %%
#Tic Tac Toe Game.....

# %%
import random

def display(board):
    print(f'''
    {board[7]}|{board[8]}|{board[9]}                        7 | 8 | 9 
    ---+---+---                       ---+---+---
    {board[4]}|{board[5]}|{board[6]}      Positions-->      4 | 5 | 6 
    ---+---+---                       ---+---+---
    {board[1]}|{board[2]}|{board[3]}                        1 | 2 | 3 
    ''')
    
def valid_input():
    while True:
        pos = input("Enter position: ")
        if pos != ' ':
            if int(pos) in range(1,10):
                pos = int(pos)
                break
            print("Not a valid position\n")
        else:
            print("Thank you for playing Tic-Tac-Toe game!")
            exit()
    return int(pos)


def valid_pos(turn,board):
    print(f'{turn} chance')
    pos = valid_input()
    while True:
        if board[pos] == '   ':
            board[pos] = turn
            break
        else:
            print('Cannot overwrite, Please select a new position')
            pos = valid_input()


def user_input(board,symbol):
    sym1, sym2 = symbol[random.randint(0,1)]
    print(f'{sym1} is going first\n\n')
    display(board)
    for i in range(9):
        if i%2==0:
            turn = ' '+sym1+' '
            valid_pos(turn,board)
        else:
            turn = ' '+sym2+' '
            valid_pos(turn,board)
        display(board)
        if i>=4:
            if check(board):
                display(board)
                print(f"'{turn}' WON")
                break
        if i==8:
            print("Nobody Won!It's a tie..")
            
def check(board):
    check = 0
    #row
    if board[1] == board[2] == board[3] != '   ' or board[4] == board[5] == board[6] != '   ' or board[7] == board[8] == board[9] !='   ':
        check = 1
    #column
    elif board[1] == board[4] == board[7] != '   ' or board[2] == board[5] == board[8] != '   ' or board[3] == board[6] == board[9] !='   ':
        check = 1
    #diagonal
    elif board[1] == board[5] == board[9] != '   ' or board[3] == board[5] == board[7] != '   ':
        check = 1
        
    return check

    
def playgame():
    board = ["This is just a dummy index :", '   ', '   ', '   ', '   ', '   ', '   ', '   ', '   ', '   ']
    symbol = [('X',' O'),('O','X')]
    while True:
        marker = input("Enter your marker : ").upper()
        if marker == 'X' or marker == 'O':
            user_input(board,symbol)
            break
        else:
            print('Wrong Marker(X,O). Please enter again...\n')
    
def main():
    print("Welcome to Tic-Tac-Toe game!!!\n")
    next = 'Y'
    while next == 'Y':
        print("Tip : Press [space] to exit from the game")
        playgame()
        next = input("Press 'Y/y' to play again: ").upper()
main()
# Out:
# Welcome to Tic-Tac-Toe game!!!
#
# Tip : Press [space] to exit from the game
# Enter your marker : x
# O is going first
#
#
#
#        |   |                           7 | 8 | 9
#     ---+---+---                       ---+---+---
#        |   |         Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#        |   |                           1 | 2 | 3
#
#  O  chance
# Enter position: 1
#
#        |   |                           7 | 8 | 9
#     ---+---+---                       ---+---+---
#        |   |         Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O |   |                           1 | 2 | 3
#
#  X  chance
# Enter position: 2
#
#        |   |                           7 | 8 | 9
#     ---+---+---                       ---+---+---
#        |   |         Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X |                           1 | 2 | 3
#
#  O  chance
# Enter position: 3
#
#        |   |                           7 | 8 | 9
#     ---+---+---                       ---+---+---
#        |   |         Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X | O                         1 | 2 | 3
#
#  X  chance
# Enter position: 2
# Cannot overwrite, Please select a new position
# Enter position: 5
#
#        |   |                           7 | 8 | 9
#     ---+---+---                       ---+---+---
#        | X |         Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X | O                         1 | 2 | 3
#
#  O  chance
# Enter position: 8
#
#        | O |                           7 | 8 | 9
#     ---+---+---                       ---+---+---
#        | X |         Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X | O                         1 | 2 | 3
#
#  X  chance
# Enter position: 9
#
#        | O | X                         7 | 8 | 9
#     ---+---+---                       ---+---+---
#        | X |         Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X | O                         1 | 2 | 3
#
#  O  chance
# Enter position: 6
#
#        | O | X                         7 | 8 | 9
#     ---+---+---                       ---+---+---
#        | X | O       Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X | O                         1 | 2 | 3
#
#  X  chance
# Enter position: 4
#
#        | O | X                         7 | 8 | 9
#     ---+---+---                       ---+---+---
#      X | X | O       Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X | O                         1 | 2 | 3
#
#  O  chance
# Enter position: 3
# Cannot overwrite, Please select a new position
# Enter position: 7
#
#      O | O | X                         7 | 8 | 9
#     ---+---+---                       ---+---+---
#      X | X | O       Positions-->      4 | 5 | 6
#     ---+---+---                       ---+---+---
#      O | X | O                         1 | 2 | 3
#
# Nobody Won!It's a tie..
# Press 'Y/y' to play again: n
